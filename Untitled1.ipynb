# %%
import pandas as pd 
from xml.dom import minidom
from xml.etree.ElementTree import parse
import spacy as sp
nlp = sp.load('en_core_web_sm')

# %%
# Leer country_CR
doc_CR = parse('Informacion_Categorizada/TASS2019_country_CR_train.xml')
doc_CR

# %%
df = pd.read_xml('Informacion_Categorizada/TASS2019_country_CR_train.xml')
df.head(100)
# Out:
#                tweetid        user  \
# 0   768225400254111744    14628107
# 1   770077064833671168   713600676
# 2   771207534342320128   120940293
# 3   771900763987513345  2827444381
# 4   772550560998301697    60878511
# ..                 ...         ...
# 95  777260686258819072    37989014
# 96  778387007831552000    50489263
# 97  778399423256592384    69747215
# 98  778399123007569920   108429729
# 99  779322857750827008    14628107
#
#                                               content  \
# 0                  @NoilyMV yo soy totalmente puntual
# 1   @SandraCauffman Hola Sandrita. No le habia des...
# 2   Si andan haciendo eso mejor se quedaran callad...
# 3                      Que pereza quiero choco banano
# 4   @robertobrenes Bueno, no es tanto lo mayor com...
# ..                                                ...
# 95                    @atrejoscr se ve fea en general
# 96  @GaboJimenex jajaja. Yo me pegué el susto de l...
# ...

# %%
lista_CR=[]
lista_Sent=[]
for item in doc_CR.iterfind('tweet'):
    lista_CR.append(item.findtext('content'))
    lista_Sent.append(item.find('sentiment').find("polarity").findtext('value'))
print(lista_CR,lista_Sent)
# Out:
# ['@NoilyMV yo soy totalmente puntual', '@SandraCauffman Hola Sandrita. No le habia deseado un feliz dia de la madre, tarde pero seguro.¿ Sabe usted si Juno ha tomado mas fotos ?', 'Si andan haciendo eso mejor se quedaran calladitas jaja pero así se están quemando ellas mismas e insinuando que son unas metidas', 'Que pereza quiero choco banano', '@robertobrenes Bueno, no es tanto lo mayor como cuánto de campo sea usted. Sos cartaguito en cada aspecto de tu vida, por lo visto.', 'Pasé todo el día buscando mi Baby Lips y lo acabo de encontrar. Estaba en la mesita de noche de fijo lo puse ahí dormida', '@doriamdiaz El de Halfon de Germinal se ve mortal. Y los de Mary Jo Bang se fueron volando, pero todavía quedan. En Duluoz hay de Salcedo', 'Ahorita me van a cambiar las ligas de los brakets, Tengo alfajores argentinos en mi bulto, tengo hambre , ¿QUÉ HAGO? no puedo esperar más', 'El amor es paciente, es bondadoso, no es envidioso ni orgulloso, no es egoísta, no guarda rencor. 1 Corintios
# ...

# %%
for i in range (len(lista_CR)):
    print(lista_CR[i]+ " - " +lista_Sent[i])
# Out:
# @NoilyMV yo soy totalmente puntual - NONE
# @SandraCauffman Hola Sandrita. No le habia deseado un feliz dia de la madre, tarde pero seguro.¿ Sabe usted si Juno ha tomado mas fotos ? - P
# Si andan haciendo eso mejor se quedaran calladitas jaja pero así se están quemando ellas mismas e insinuando que son unas metidas - N
# Que pereza quiero choco banano - N
# @robertobrenes Bueno, no es tanto lo mayor como cuánto de campo sea usted. Sos cartaguito en cada aspecto de tu vida, por lo visto. - N
# Pasé todo el día buscando mi Baby Lips y lo acabo de encontrar. Estaba en la mesita de noche de fijo lo puse ahí dormida - NEU
# @doriamdiaz El de Halfon de Germinal se ve mortal. Y los de Mary Jo Bang se fueron volando, pero todavía quedan. En Duluoz hay de Salcedo - P
# Ahorita me van a cambiar las ligas de los brakets, Tengo alfajores argentinos en mi bulto, tengo hambre , ¿QUÉ HAGO? no puedo esperar más - NONE
# ...

# %%
#len(lista_CR)
#len(lista_Sent)
# Out:
# 777

# %%
# In [1]:
import xml.etree.ElementTree as et
# In [2]:
import pandas as pd
# In [3]:
xml_data = open('Informacion_Categorizada/TASS2019_country_CR_train.xml', 'r').read()  
# In [4]:
root = et.XML(xml_data) 
 
data = []
cols = []
for i, child in enumerate(tweets):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

for i, subsubsubsubchild in enumerate(subsubsubchild):
    data.append([subsubsubsubsubchild.text for subsubsubsubsubchild in subsubsubsubchild])
    cols.append(subsubsubsubchild.tag)

print(data,cols)
# Out:
# [['768225400254111744', '14628107', '@NoilyMV yo soy totalmente puntual', 'Tue Aug 23 23:16:23 +0000 2016', 'es', '\n\t\t\t'], ['770077064833671168', '713600676', '@SandraCauffman Hola Sandrita. No le habia deseado un feliz dia de la madre, tarde pero seguro.¿ Sabe usted si Juno ha tomado mas fotos ?', 'Mon Aug 29 01:54:14 +0000 2016', 'es', '\n\t\t\t'], ['771207534342320128', '120940293', 'Si andan haciendo eso mejor se quedaran calladitas jaja pero así se están quemando ellas mismas e insinuando que son unas metidas', 'Thu Sep 01 04:46:19 +0000 2016', 'es', '\n\t\t\t'], ['771900763987513345', '2827444381', 'Que pereza quiero choco banano', 'Sat Sep 03 02:40:58 +0000 2016', 'es', '\n\t\t\t'], ['772550560998301697', '60878511', '@robertobrenes Bueno, no es tanto lo mayor como cuánto de campo sea usted. Sos cartaguito en cada aspecto de tu vida, por lo visto.', 'Sun Sep 04 21:43:01 +0000 2016', 'es', '\n\t\t\t'], ['772594807357124608', '761015519646363648', 'Pasé todo el día buscando 
# ...

# %%
from string import punctuation
print(punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
signos_delet=list()
for text in data_CR:
  text = text.lower()
  text = "".join([ch for ch in text if ch not in punctuation])
  signos_delet.append(text)
all_text = " ".join(all_reviews)
all_words = all_text.split()
